# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([2,3,4],[5,6,1])
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([2,3,4],[5,6,1])
plt.title('shreepatil ka chart')
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
plt.style.use('ggplot')
x=[1,9,8]
x2=[2,3,4]
x3=[2,3,4]
x4=[6,7,8]

plt.plot(x,x2,label='first')
plt.plot(x3,x4,label = 'second')

plt.legend()
plt.title('shreepatil ka chart')
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
x=[1,9,8]
x2=[2,3,4]
x3=[2,3,4]
x4=[6,7,8]

plt.scatter(x,x2,label='first')
plt.scatter(x3,x4,label = 'second')

plt.legend()
plt.title('shreepatil ka chart')
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
x=[1,9,8]
x2=[2,3,4]
x3=[2,3,4]
x4=[6,7,8]

plt.hist(x,x2,label='first')
plt.hist(x3,x4,label = 'second')

plt.legend()
plt.title('shreepatil ka chart')
plt.show()
